# %% [markdown]
# # UNIVERSIDAD NACIONAL DEL OESTE
# ## Escuela de Informática
# ### PROGRAMACIÓN CON OBJETOS I
# #### Profesores: Mag. Ing. Pablo Pandolfo / Lic. Leandro Politano
# #### Examen Final - Julio 2026

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# ### 1. Completar
# * Los atributos declarados como privados forman parte del principio de ______________
# * Una ____________________________ permite almacenar elementos sin repetirlos
# * Un ____________________________ relaciona una clave única con un valor asociado
# * El bloque __________________ se ejecuta independientemente de que ocurra o no una excepción
# * Cuando un archivo se abre en modo append ("a"), la información nueva se escribe _____________

# %% [markdown]
# ### 2. Verdadero o Falso
# * Una clase hija puede agregar nuevos atributos además de los heredados
# * Un método estático necesita obligatoriamente una instancia para poder ejecutarse
# * Una lista puede almacenar objetos de distintas clases
# * Si ocurre una excepción y no existe un bloque catch/except, el programa puede finalizar con error

# %% [markdown]
# ### 3. Seleccionar la opción correcta
# * **La herencia sirve para:**
#     * Reutilizar código
#     * Eliminar colecciones
#     * Evitar crear objetos
#     * Reemplazar los diccionarios
# * **¿Cuándo se ejecuta el constructor?**
#     * Al crear el objeto
#     * Al eliminarlo
#     * Al cerrar el programa
#     * Al llamar cualquier método
# * **¿Qué ocurre si un archivo no existe y se abre en modo "w"?**
#     * Se produce un error
#     * Se crea automáticamente
#     * Se abre sólo para lectura
#     * Se elimina el directorio
# * **¿Qué ventaja ofrecen los decoradores?**
#     * Reutilizar código sin modificar la implementación de las funciones originales
#     * Evitar el uso de clases
#     * Eliminar la necesidad de crear funciones
#     * Reemplazar el encapsulamiento

# %% [markdown]
# ### 4. Practica
# * Crear un método **contar_lineas(nombre_archivo)** que retorne la cantidad de líneas existentes en el archivo
# * Crear un método que reciba una lista de palabras y devuelva un diccionario donde la clave sea cada palabra y el valor su cantidad de letras
# * Crear una clase **Alumno** cuyo constructor reciba **nombre**, **legajo**, **carrera**
# * Mostrar la creación de dos objetos **Alumno**
# * Crear un método que reciba una lista de objetos Alumno y devuelva un booleano indicando si existe un alumno cuyo legajo coincida con uno recibido por parámetro
